# %%
#train = pd.read_csv('xxx.csv')
#train['y'] = train['y'].map({'A':1, 'B':2, 'C':3, 'C':4, 'E':5, 'F':'w'})
#print(train)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('perovskite-molecule.xlsx')
data
# Out:
#                                        DOI  Number  \
# 0        doi.org/10.1038/s41566-019-0390-x     1.0
# 1           doi.org/10.1002/cssc.202101573     2.0
# 2                                      NaN     NaN
# 3                                      NaN     NaN
# 4                                      NaN     NaN
# 5                                      NaN     NaN
# 6                                      NaN     NaN
# 7                                      NaN     NaN
# 8                                      NaN     NaN
# 9                                      NaN     NaN
# 10                                     NaN     NaN
# 11                                     NaN     NaN
# 12                                     NaN     NaN
# 13                                     NaN     NaN
# 14                                     NaN     NaN
# 15                                     NaN     NaN
# 16                                     NaN     NaN
# ...

# %%
plt.scatter(x=data['t'], y=data['PCE'])

# %%
plt.scatter(x=data['μ'], y=data['PCE'])

# %%
plt.scatter(x=data['RA'], y=data['PCE'])

# %%
plt.scatter(x=data['RB'], y=data['PCE'])

# %%
plt.scatter(x=data['RX'], y=data['PCE'])

# %%
data['Passivation-Molecules']
# Out:
# 0                                                   EDEA
# 1                                               Pyridine
# 2                                             Thiophene
# 3                                                  IPFB
# 4                                                   PCBM
# 5                                                    PTT
# 6                                                   EDT
# 7                                              Caffeine
# 8                                                4-DMABA
# 9                                                   SP3
# 10                                                 2-MP
# 11                                     Choline Chloride
# 12                             L-α-phosphatidyl Choline
# 13                                                 DPSI
# 14                                              ImAcHCl
# 15                                           PCBB-3N-3I
# 16                                                  PPS
# ...

# %%
data1 = data['Passivation-Molecules'].map({'EDEA':1,'Pyridine':2,'Thiophene':3,"IPFB":4,'PCBM':5})
data1
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      NaN
# 4      5.0
#       ...
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# Name: Passivation-Molecules, Length: 146, dtype: float64

# %%
Descriptor1={'EDEA':1,'Pyridine':2,'Thiophene':3,"IPFB":4,'PCBM':5}
data1 = data['Passivation-Molecules'].map(Descriptor1)
data1
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      NaN
# 4      5.0
#       ...
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# Name: Passivation-Molecules, Length: 146, dtype: float64

# %%
data2 = data['Passivation-Molecules'].replace(['EDEA','Pyridine','Thiophene'],[1,2,3])
data2
# Out:
# 0               1
# 1               2
# 2      Thiophene
# 3           IPFB
# 4            PCBM
#           ...
# 141           NaN
# 142           NaN
# 143           NaN
# 144           NaN
# 145           NaN
# Name: Passivation-Molecules, Length: 146, dtype: object

# %%
class_mapping = {'EDEA':1,'Pyridine':2,'Thiophene ':3,"IPFB ":4,'PCBM':5}
data3 = data['Passivation-Molecules'].map(class_mapping)
data3
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN
# 50     NaN
# 51     NaN
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56     NaN
# 57     NaN
# 58     NaN
# 59     NaN
# 60     NaN
# 61     NaN
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# 69     NaN
# 70     5.0
# 71     NaN
# 72     NaN
# 73     NaN
# 74     NaN
# 75     NaN
# ...

# %%
class_mapping = {'EDEA':1,'Pyridine':2,'PCBM':5, 'PTT':6, 'EDT':7}
data3 = data['Passivation-Molecules'].map(class_mapping)
pd.set_option('display.max_rows', None)
data3
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      NaN
# 4      5.0
# 5      6.0
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN
# 50     NaN
# 51     NaN
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56     NaN
# 57     NaN
# 58     NaN
# 59     NaN
# 60     NaN
# 61     NaN
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# 69     NaN
# 70     5.0
# 71     NaN
# 72     NaN
# 73     NaN
# 74     NaN
# 75     NaN
# ...

# %%
da
